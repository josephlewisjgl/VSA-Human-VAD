# %% [markdown]
# # Run anomaly detection pipelines
#
# This notebook runs the corresponding anomaly detection pipelines
#
# Arguments are taken by the module according to the system being run and the parameters used.
#
# To test the constrained latency you will need to build and run the docker image and follow the readme instructions.

# %%
! pip install pandas torch-hd torch numpy scikit-learn

# %% [markdown]
# # Post-hoc system - No pose estimation

# %%
! python detection.py --clusters 10 --bins 3 --temporal True --odhd True --step 5 --stride 25 --output posthocsystem --system post-hoc --iter 10
# Out:
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|██████████████████████████████████| 93451/93451 [00:05<00:00, 17702.73it/s]
# Temporal encoding
# 93451it [00:07, 12929.81it/s]
# Clustering with 10 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|██████████████████████████████████| 78434/78434 [00:04<00:00, 16311.68it/s]
# 78434it [00:05, 13634.37it/s]
# Evaluating test vectors
# Processed in 24.57 seconds
# Frames: 15315
# Efficiency: 1.6042845567534494ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|██████████████████████████████████| 93451/93451 [00:05<00:00, 18134.89it/s]
# Temporal encoding
# 93451it [00:06, 13395.67it/s]
# Clustering with 10 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|██████████████████████████████████| 78434/78434 [00:04<00:00, 17129.00it/s]
# 78434it [00:05, 13626.58it/s]
# Evaluating test vectors
# Processed in 24.19 seconds
# Frames: 15315
# Efficiency: 1.5792899142672256ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|██████████████████████████████████| 93451/93451 [00:05<00:00, 16573.12it/s]
# Temporal encoding
# 93451it [00:06, 13664.34it/s]
# Clustering with 10 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|██████████████████████████████████| 78434/78434 [00:05<00:00, 15335.16it/s]
# 78434it [00:05, 13842.60it/s]
# Evaluating test vectors
# Processed in 25.69 seconds
# Frames: 15315
# Efficiency: 1.6776973501436467ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|██████████████████████████████████| 93451/93451 [00:05<00:00, 17374.39it/s]
# Temporal encoding
# 93451it [00:07, 13095.76it/s]
# Clustering with 10 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|██████████████████████████████████| 78434/78434 [00:04<00:00, 16601.38it/s]
# 78434it [00:06, 12910.62it/s]
# Evaluating test vectors
# Processed in 24.33 seconds
# Frames: 15315
# Efficiency: 1.5887377661425734ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|██████████████████████████████████| 93451/93451 [00:05<00:00, 17977.11it/s]
# Temporal encoding
# 93451it [00:06, 14094.23it/s]
# Clustering with 10 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|██████████████████████████████████| 78434/78434 [00:04<00:00, 17190.55it/s]
# 78434it [00:05, 13416.81it/s]
# Evaluating test vectors
# Processed in 24.43 seconds
# Frames: 15315
# Efficiency: 1.5951201451046577ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|██████████████████████████████████| 93451/93451 [00:05<00:00, 15846.30it/s]
# Temporal encoding
# 93451it [00:07, 11892.60it/s]
# Clustering with 10 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|██████████████████████████████████| 78434/78434 [00:04<00:00, 16760.50it/s]
# 78434it [00:05, 13452.56it/s]
# Evaluating test vectors
# Processed in 25.62 seconds
# Frames: 15315
# Efficiency: 1.6730948830211314ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|██████████████████████████████████| 93451/93451 [00:05<00:00, 16200.65it/s]
# Temporal encoding
# 93451it [00:07, 12773.21it/s]
# Clustering with 10 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|██████████████████████████████████| 78434/78434 [00:04<00:00, 16501.75it/s]
# 78434it [00:06, 12716.90it/s]
# Evaluating test vectors
# Processed in 24.67 seconds
# Frames: 15315
# Efficiency: 1.6110985332791647ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|██████████████████████████████████| 93451/93451 [00:05<00:00, 17837.45it/s]
# Temporal encoding
# 93451it [00:06, 14020.53it/s]
# Clustering with 10 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|██████████████████████████████████| 78434/78434 [00:04<00:00, 15781.22it/s]
# 78434it [00:05, 13501.33it/s]
# Evaluating test vectors
# Processed in 27.05 seconds
# Frames: 15315
# Efficiency: 1.7663505004972482ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|██████████████████████████████████| 93451/93451 [00:05<00:00, 16662.05it/s]
# Temporal encoding
# 93451it [00:07, 12571.77it/s]
# Clustering with 10 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|██████████████████████████████████| 78434/78434 [00:05<00:00, 15553.16it/s]
# 78434it [00:06, 12724.38it/s]
# Evaluating test vectors
# Processed in 25.09 seconds
# Frames: 15315
# Efficiency: 1.6381556716106935ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|██████████████████████████████████| 93451/93451 [00:05<00:00, 18192.10it/s]
# Temporal encoding
# 93451it [00:06, 14823.30it/s]
# Clustering with 10 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|██████████████████████████████████| 78434/78434 [00:04<00:00, 17455.60it/s]
# 78434it [00:06, 12946.76it/s]
# Evaluating test vectors
# Processed in 24.07 seconds
# Frames: 15315
# Efficiency: 1.5714363144224779ms per frame

# %% [markdown]
# ## Edge system - Pose estimation
#
# (just one iter to assess latency)

# %%
! python detection.py --clusters 1 --bins 3 --temporal True --odhd True --step 5 --stride 25 --output edgesystem --system edge --iter 1 --videodir '../Avenue Dataset/testing_videos'
# Out:
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|██████████████████████████████████| 21486/21486 [00:01<00:00, 17791.55it/s]
# Temporal encoding
# 21486it [00:01, 17380.02it/s]
# Clustering with 1 clusters
# Estimating test poses
# Processing video: 12_frames
#   0%|                                                  | 0/1273 [00:00<?, ?it/s]Loading ../yolo11s-pose_openvino_model for OpenVINO inference...
# Using OpenVINO LATENCY mode for batch=1 inference...
#   1%|▌                                        | 16/1273 [00:01<01:14, 16.87it/s]Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|██████████████████████████████████| 21486/21486 [00:01<00:00, 14544.88it/s]
# Temporal encoding
# 100%|███████████████████████████████████████| 1273/1273 [00:18<00:00, 69.50it/s]
# Processed 12_frames with 1850 detections so far.
# Processing video: 02_frames
# 100%|███████████████████████████████████████| 1212/1212 [00:14<00:00, 83.62it/s]
# Processed 02_frames with 4343 detections so far.
# Processing video: 10_frames
# 100%|█████████████████████████████████████████| 842/842 [00:10<00:00, 82.63it/s]
# Processed 10_frames with 6178 detections so far.
# Processing video: 14_frames
# 100%|█████████████████████████████████████████| 508/508 [00:06<00:00, 84.43it/s]
# Processed 14_frames with 7343 detections so far.
# Processing video: 18_frames
# 100%|█████████████████████████████████████████| 295/295 [00:03<00:00, 81.16it/s]
# Processed 18_frames with 7658 detections so far.
# Processing video: 06_frames
# 100%|███████████████████████████████████████| 1285/1285 [00:15<00:00, 80.66it/s]
# Processed 06_frames with 8788 detections so far.
# Processing video: 20_frames
# 100%|█████████████████████████████████████████| 275/275 [00:03<00:00, 81.40it/s]
# Processed 20_frames with 9284 detections so far.
# Processing video: 04_frames
# 100%|█████████████████████████████████████████| 948/948 [00:11<00:00, 82.53it/s]
# Processed 04_frames with 10205 detections so far.
# Processing video: 16_frames
# 100%|█████████████████████████████████████████| 741/741 [00:08<00:00, 82.86it/s]
# Processed 16_frames with 11219 detections so far.
# Processing video: 08_frames
# 100%|███████████████████████████████████████████| 37/37 [00:00<00:00, 85.18it/s]
# Processed 08_frames with 11326 detections so far.
# Processing video: 13_frames
# 100%|█████████████████████████████████████████| 550/550 [00:06<00:00, 85.25it/s]
# Processed 13_frames with 11750 detections so far.
# Processing video: 01_frames
# 100%|███████████████████████████████████████| 1440/1440 [00:17<00:00, 81.08it/s]
# Processed 01_frames with 13882 detections so far.
# Processing video: 03_frames
# 100%|█████████████████████████████████████████| 925/925 [00:11<00:00, 79.72it/s]
# Processed 03_frames with 14748 detections so far.
# Processing video: 11_frames
# 100%|█████████████████████████████████████████| 473/473 [00:06<00:00, 77.34it/s]
# Processed 11_frames with 15600 detections so far.
# Processing video: 15_frames
# 100%|███████████████████████████████████████| 1002/1002 [00:13<00:00, 75.78it/s]
# Processed 15_frames with 17113 detections so far.
# Processing video: 07_frames
# 100%|█████████████████████████████████████████| 606/606 [00:08<00:00, 71.87it/s]
# Processed 07_frames with 18073 detections so far.
# Processing video: 19_frames
# 100%|█████████████████████████████████████████| 249/249 [00:03<00:00, 69.29it/s]
# Processed 19_frames with 18697 detections so far.
# Processing video: 05_frames
# 100%|███████████████████████████████████████| 1008/1008 [00:13<00:00, 73.56it/s]
# Processed 05_frames with 20864 detections so far.
# Processing video: 09_frames
# 100%|███████████████████████████████████████| 1177/1177 [00:15<00:00, 73.57it/s]
# Processed 09_frames with 23320 detections so far.
# Processing video: 17_frames
# 100%|█████████████████████████████████████████| 427/427 [00:05<00:00, 74.82it/s]
# Processed 17_frames with 23814 detections so far.
# Processing video: 21_frames
# 100%|███████████████████████████████████████████| 78/78 [00:01<00:00, 76.12it/s]
# Processed 21_frames with 24086 detections so far.
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|██████████████████████████████████| 24086/24086 [00:01<00:00, 12446.42it/s]
# 24086it [00:01, 17201.68it/s]
# Evaluating test vectors
# Processed in 203.12 seconds
# Frames: 13334
# Efficiency: 15.2334543259333ms per frame
# /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py:301: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown: {'/loky-41494-ejg57uo2'}
#   warnings.warn(

# %% [markdown]
# ## Edge system - No pose estimation

# %%
! python detection.py --clusters 1 --bins 3 --temporal True --odhd True --step 5 --stride 25 --output edgesystem --system edge --iter 10
# Out:
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|██████████████████████████████████| 21486/21486 [00:01<00:00, 17770.77it/s]
# Temporal encoding
# 21486it [00:01, 18329.20it/s]
# Clustering with 1 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|██████████████████████████████████| 24086/24086 [00:01<00:00, 13069.15it/s]
# 24086it [00:01, 17998.93it/s]
# Evaluating test vectors
# Processed in 5.87 seconds
# Frames: 13334
# Efficiency: 0.44045729742283335ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|██████████████████████████████████| 21486/21486 [00:02<00:00, 10655.30it/s]
# Temporal encoding
# 21486it [00:01, 11299.32it/s]
# Clustering with 1 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|██████████████████████████████████| 24086/24086 [00:02<00:00, 10274.08it/s]
# 24086it [00:01, 18394.11it/s]
# Evaluating test vectors
# Processed in 6.35 seconds
# Frames: 13334
# Efficiency: 0.47601297446342894ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|███████████████████████████████████| 21486/21486 [00:02<00:00, 9690.84it/s]
# Temporal encoding
# 21486it [00:02, 9872.97it/s]
# Clustering with 1 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|███████████████████████████████████| 24086/24086 [00:03<00:00, 7710.26it/s]
# 24086it [00:01, 17002.45it/s]
# Evaluating test vectors
# Processed in 7.27 seconds
# Frames: 13334
# Efficiency: 0.5449462512702764ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|███████████████████████████████████| 21486/21486 [00:02<00:00, 8757.60it/s]
# Temporal encoding
# 21486it [00:02, 10053.53it/s]
# Clustering with 1 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|███████████████████████████████████| 24086/24086 [00:03<00:00, 7970.76it/s]
# 24086it [00:01, 16239.76it/s]
# Evaluating test vectors
# Processed in 7.20 seconds
# Frames: 13334
# Efficiency: 0.540184191504536ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|███████████████████████████████████| 21486/21486 [00:02<00:00, 8527.86it/s]
# Temporal encoding
# 21486it [00:02, 10393.05it/s]
# Clustering with 1 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|███████████████████████████████████| 24086/24086 [00:02<00:00, 9057.21it/s]
# 24086it [00:01, 17029.85it/s]
# Evaluating test vectors
# Processed in 6.79 seconds
# Frames: 13334
# Efficiency: 0.5094202022171993ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|███████████████████████████████████| 21486/21486 [00:02<00:00, 8030.83it/s]
# Temporal encoding
# 21486it [00:02, 9031.19it/s]
# Clustering with 1 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|███████████████████████████████████| 24086/24086 [00:02<00:00, 8290.49it/s]
# 24086it [00:01, 14046.01it/s]
# Evaluating test vectors
# Processed in 7.42 seconds
# Frames: 13334
# Efficiency: 0.5563881080047255ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|███████████████████████████████████| 21486/21486 [00:02<00:00, 9713.05it/s]
# Temporal encoding
# 21486it [00:02, 10063.44it/s]
# Clustering with 1 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|███████████████████████████████████| 24086/24086 [00:02<00:00, 8048.29it/s]
# 24086it [00:01, 14081.78it/s]
# Evaluating test vectors
# Processed in 7.35 seconds
# Frames: 13334
# Efficiency: 0.5512397579297823ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|██████████████████████████████████| 21486/21486 [00:02<00:00, 10023.97it/s]
# Temporal encoding
# 21486it [00:02, 10130.73it/s]
# Clustering with 1 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|███████████████████████████████████| 24086/24086 [00:02<00:00, 8814.66it/s]
# 24086it [00:01, 14732.85it/s]
# Evaluating test vectors
# Processed in 7.10 seconds
# Frames: 13334
# Efficiency: 0.5324457974488971ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|███████████████████████████████████| 21486/21486 [00:02<00:00, 9247.95it/s]
# Temporal encoding
# 21486it [00:02, 8712.61it/s]
# Clustering with 1 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|███████████████████████████████████| 24086/24086 [00:03<00:00, 7693.78it/s]
# 24086it [00:01, 13610.36it/s]
# Evaluating test vectors
# Processed in 7.66 seconds
# Frames: 13334
# Efficiency: 0.5743092676680253ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|███████████████████████████████████| 21486/21486 [00:02<00:00, 8919.68it/s]
# Temporal encoding
# 21486it [00:02, 10188.87it/s]
# Clustering with 1 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|███████████████████████████████████| 24086/24086 [00:03<00:00, 7513.31it/s]
# 24086it [00:01, 12855.20it/s]
# Evaluating test vectors
# Processed in 7.67 seconds
# Frames: 13334
# Efficiency: 0.5755913531170518ms per frame

# %% [markdown]
# ## Ablations:
#
# Post hoc:
# * No ODHD
# * No Temporal
# * Increased temporal
# * Increased bins
#
# Edge:
# * No ODHD
# * No temporal
# * Increased bins

# %%
! python detection.py --clusters 1 --bins 3 --temporal True --odhd False --step 5 --stride 25 --output edgenoodhd --system edge --iter 5
! python detection.py --clusters 1 --bins 3 --temporal False --odhd True --step 5 --stride 25 --output edgenotemp --system edge --iter 5
! python detection.py --clusters 1 --bins 5 --temporal True --odhd False --step 5 --stride 25 --output edgemorebin --system edge --iter 5
# Out:
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|██████████████████████████████████| 21486/21486 [00:01<00:00, 17252.65it/s]
# Temporal encoding
# 21486it [00:01, 17797.23it/s]
# Clustering with 1 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|██████████████████████████████████| 24086/24086 [00:01<00:00, 14448.91it/s]
# 24086it [00:01, 18051.55it/s]
# Evaluating test vectors
# Processed in 5.79 seconds
# Frames: 13334
# Efficiency: 0.43389815806412746ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|███████████████████████████████████| 21486/21486 [00:02<00:00, 9840.81it/s]
# Temporal encoding
# 21486it [00:01, 12070.67it/s]
# Clustering with 1 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|███████████████████████████████████| 24086/24086 [00:02<00:00, 8943.98it/s]
# 24086it [00:01, 16496.12it/s]
# Evaluating test vectors
# Processed in 7.03 seconds
# Frames: 13334
# Efficiency: 0.5272576811432713ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|███████████████████████████████████| 21486/21486 [00:02<00:00, 9958.85it/s]
# Temporal encoding
# 21486it [00:01, 10769.68it/s]
# Clustering with 1 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|██████████████████████████████████| 24086/24086 [00:02<00:00, 10617.25it/s]
# 24086it [00:01, 16456.78it/s]
# Evaluating test vectors
# Processed in 6.72 seconds
# Frames: 13334
# Efficiency: 0.504261141723111ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|███████████████████████████████████| 21486/21486 [00:02<00:00, 7832.24it/s]
# Temporal encoding
# 21486it [00:02, 9099.84it/s]
# Clustering with 1 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|██████████████████████████████████| 24086/24086 [00:02<00:00, 11465.71it/s]
# 24086it [00:01, 14065.80it/s]
# Evaluating test vectors
# Processed in 6.94 seconds
# Frames: 13334
# Efficiency: 0.5207203381133433ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|███████████████████████████████████| 21486/21486 [00:02<00:00, 9747.47it/s]
# Temporal encoding
# 21486it [00:01, 13599.12it/s]
# Clustering with 1 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|██████████████████████████████████| 24086/24086 [00:01<00:00, 12990.71it/s]
# 24086it [00:01, 16132.29it/s]
# Evaluating test vectors
# Processed in 6.11 seconds
# Frames: 13334
# Efficiency: 0.4580694999368684ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|██████████████████████████████████| 21486/21486 [00:01<00:00, 18439.13it/s]
# Temporal encoding
# 21486it [00:01, 17641.20it/s]
# Clustering with 1 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|██████████████████████████████████| 24086/24086 [00:01<00:00, 18095.83it/s]
# 24086it [00:01, 17608.57it/s]
# Evaluating test vectors
# Processed in 5.63 seconds
# Frames: 13334
# Efficiency: 0.42242928389507345ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|██████████████████████████████████| 21486/21486 [00:01<00:00, 15287.33it/s]
# Temporal encoding
# 21486it [00:01, 16222.90it/s]
# Clustering with 1 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|██████████████████████████████████| 24086/24086 [00:01<00:00, 12387.90it/s]
# 24086it [00:01, 17282.27it/s]
# Evaluating test vectors
# Processed in 6.26 seconds
# Frames: 13334
# Efficiency: 0.4695189737640651ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|██████████████████████████████████| 21486/21486 [00:01<00:00, 10905.13it/s]
# Temporal encoding
# 21486it [00:01, 12850.44it/s]
# Clustering with 1 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|██████████████████████████████████| 24086/24086 [00:01<00:00, 13601.77it/s]
# 24086it [00:01, 18217.85it/s]
# Evaluating test vectors
# Processed in 5.98 seconds
# Frames: 13334
# Efficiency: 0.44825312364256975ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|██████████████████████████████████| 21486/21486 [00:01<00:00, 13252.02it/s]
# Temporal encoding
# 21486it [00:01, 12927.46it/s]
# Clustering with 1 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|██████████████████████████████████| 24086/24086 [00:02<00:00, 11584.45it/s]
# 24086it [00:01, 17796.29it/s]
# Evaluating test vectors
# Processed in 6.39 seconds
# Frames: 13334
# Efficiency: 0.47910581808746777ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|██████████████████████████████████| 21486/21486 [00:01<00:00, 11919.11it/s]
# Temporal encoding
# 21486it [00:01, 13305.06it/s]
# Clustering with 1 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|██████████████████████████████████| 24086/24086 [00:01<00:00, 12094.52it/s]
# 24086it [00:01, 18239.39it/s]
# Evaluating test vectors
# Processed in 6.05 seconds
# Frames: 13334
# Efficiency: 0.45407454935671493ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|██████████████████████████████████| 21486/21486 [00:01<00:00, 18105.93it/s]
# Temporal encoding
# 21486it [00:01, 18460.66it/s]
# Clustering with 1 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|██████████████████████████████████| 24086/24086 [00:01<00:00, 15860.59it/s]
# 24086it [00:01, 17756.24it/s]
# Evaluating test vectors
# Processed in 5.78 seconds
# Frames: 13334
# Efficiency: 0.4338137084654251ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|██████████████████████████████████| 21486/21486 [00:01<00:00, 13553.82it/s]
# Temporal encoding
# 21486it [00:01, 16982.24it/s]
# Clustering with 1 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|██████████████████████████████████| 24086/24086 [00:01<00:00, 12927.31it/s]
# 24086it [00:01, 17418.63it/s]
# Evaluating test vectors
# Processed in 6.25 seconds
# Frames: 13334
# Efficiency: 0.4686631236599181ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|███████████████████████████████████| 21486/21486 [00:02<00:00, 9404.94it/s]
# Temporal encoding
# 21486it [00:01, 13025.09it/s]
# Clustering with 1 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|██████████████████████████████████| 24086/24086 [00:01<00:00, 13793.79it/s]
# 24086it [00:01, 16205.51it/s]
# Evaluating test vectors
# Processed in 6.17 seconds
# Frames: 13334
# Efficiency: 0.46295897614138765ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|██████████████████████████████████| 21486/21486 [00:01<00:00, 11373.36it/s]
# Temporal encoding
# 21486it [00:01, 14677.46it/s]
# Clustering with 1 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|██████████████████████████████████| 24086/24086 [00:01<00:00, 13198.63it/s]
# 24086it [00:01, 17824.53it/s]
# Evaluating test vectors
# Processed in 6.04 seconds
# Frames: 13334
# Efficiency: 0.4526131761401279ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|██████████████████████████████████| 21486/21486 [00:01<00:00, 11508.17it/s]
# Temporal encoding
# 21486it [00:01, 12348.68it/s]
# Clustering with 1 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|██████████████████████████████████| 24086/24086 [00:01<00:00, 13334.26it/s]
# 24086it [00:01, 17983.54it/s]
# Evaluating test vectors
# Processed in 6.13 seconds
# Frames: 13334
# Efficiency: 0.4598031395179356ms per frame

# %%
! python detection.py --clusters 1 --bins 3 --temporal True --odhd False --step 5 --stride 25 --output posthocnoodhd --system post-hoc --iter 5
! python detection.py --clusters 1 --bins 3 --temporal False --odhd True --step 5 --stride 25 --output posthocnotemp --system post-hoc --iter 5
! python detection.py --clusters 1 --bins 5 --temporal True --odhd False --step 5 --stride 25 --output posthocmorebin --system post-hoc --iter 5
! python detection.py --clusters 1 --bins 3 --temporal True --odhd False --step 20 --stride 10 --output posthocmoretemp --system post-hoc --iter 5
# Out:
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|██████████████████████████████████| 93451/93451 [00:05<00:00, 18088.08it/s]
# Temporal encoding
# 93451it [00:07, 12969.62it/s]
# Clustering with 1 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|██████████████████████████████████| 78434/78434 [00:04<00:00, 17490.12it/s]
# 78434it [00:05, 13594.46it/s]
# Evaluating test vectors
# Processed in 20.87 seconds
# Frames: 15315
# Efficiency: 1.3628786232126644ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|██████████████████████████████████| 93451/93451 [00:05<00:00, 17886.05it/s]
# Temporal encoding
# 93451it [00:06, 13758.58it/s]
# Clustering with 1 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|██████████████████████████████████| 78434/78434 [00:04<00:00, 17318.44it/s]
# 78434it [00:05, 14213.47it/s]
# Evaluating test vectors
# Processed in 21.17 seconds
# Frames: 15315
# Efficiency: 1.3823649325169967ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|██████████████████████████████████| 93451/93451 [00:05<00:00, 17703.44it/s]
# Temporal encoding
# 93451it [00:06, 13650.11it/s]
# Clustering with 1 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|██████████████████████████████████| 78434/78434 [00:04<00:00, 17256.95it/s]
# 78434it [00:05, 14583.09it/s]
# Evaluating test vectors
# Processed in 20.89 seconds
# Frames: 15315
# Efficiency: 1.364160961782547ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|██████████████████████████████████| 93451/93451 [00:05<00:00, 17851.41it/s]
# Temporal encoding
# 93451it [00:07, 13099.75it/s]
# Clustering with 1 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|██████████████████████████████████| 78434/78434 [00:04<00:00, 17265.53it/s]
# 78434it [00:05, 14161.35it/s]
# Evaluating test vectors
# Processed in 21.15 seconds
# Frames: 15315
# Efficiency: 1.381294096057181ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|██████████████████████████████████| 93451/93451 [00:05<00:00, 17829.65it/s]
# Temporal encoding
# 93451it [00:06, 13691.99it/s]
# Clustering with 1 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|██████████████████████████████████| 78434/78434 [00:04<00:00, 16979.61it/s]
# 78434it [00:05, 13885.19it/s]
# Evaluating test vectors
# Processed in 21.34 seconds
# Frames: 15315
# Efficiency: 1.3932995106556663ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|██████████████████████████████████| 93451/93451 [00:05<00:00, 18121.81it/s]
# Temporal encoding
# 93451it [00:05, 17022.52it/s]
# Clustering with 1 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|██████████████████████████████████| 78434/78434 [00:04<00:00, 17520.11it/s]
# 78434it [00:04, 15781.50it/s]
# Evaluating test vectors
# Processed in 20.14 seconds
# Frames: 15315
# Efficiency: 1.3152769177792083ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|██████████████████████████████████| 93451/93451 [00:05<00:00, 18033.32it/s]
# Temporal encoding
# 93451it [00:06, 13673.88it/s]
# Clustering with 1 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|██████████████████████████████████| 78434/78434 [00:04<00:00, 17504.80it/s]
# 78434it [00:04, 15704.21it/s]
# Evaluating test vectors
# Processed in 20.49 seconds
# Frames: 15315
# Efficiency: 1.3378149381930866ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|██████████████████████████████████| 93451/93451 [00:05<00:00, 17724.08it/s]
# Temporal encoding
# 93451it [00:06, 13466.02it/s]
# Clustering with 1 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|██████████████████████████████████| 78434/78434 [00:04<00:00, 17477.24it/s]
# 78434it [00:05, 14454.35it/s]
# Evaluating test vectors
# Processed in 21.37 seconds
# Frames: 15315
# Efficiency: 1.3955650709440535ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|██████████████████████████████████| 93451/93451 [00:05<00:00, 17641.75it/s]
# Temporal encoding
# 93451it [00:06, 13416.30it/s]
# Clustering with 1 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|██████████████████████████████████| 78434/78434 [00:04<00:00, 17072.93it/s]
# 78434it [00:05, 14030.78it/s]
# Evaluating test vectors
# Processed in 21.16 seconds
# Frames: 15315
# Efficiency: 1.3815559283837826ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|██████████████████████████████████| 93451/93451 [00:05<00:00, 18088.98it/s]
# Temporal encoding
# 93451it [00:07, 13219.27it/s]
# Clustering with 1 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|██████████████████████████████████| 78434/78434 [00:04<00:00, 17425.97it/s]
# 78434it [00:05, 15415.17it/s]
# Evaluating test vectors
# Processed in 20.82 seconds
# Frames: 15315
# Efficiency: 1.3596942134437473ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|██████████████████████████████████| 93451/93451 [00:05<00:00, 18379.60it/s]
# Temporal encoding
# 93451it [00:05, 16664.92it/s]
# Clustering with 1 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|██████████████████████████████████| 78434/78434 [00:04<00:00, 17583.23it/s]
# 78434it [00:05, 14694.60it/s]
# Evaluating test vectors
# Processed in 20.59 seconds
# Frames: 15315
# Efficiency: 1.3441463175296315ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|██████████████████████████████████| 93451/93451 [00:05<00:00, 18216.83it/s]
# Temporal encoding
# 93451it [00:06, 13837.09it/s]
# Clustering with 1 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|██████████████████████████████████| 78434/78434 [00:04<00:00, 17291.55it/s]
# 78434it [00:05, 13675.16it/s]
# Evaluating test vectors
# Processed in 22.03 seconds
# Frames: 15315
# Efficiency: 1.4382111103831263ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|██████████████████████████████████| 93451/93451 [00:05<00:00, 16131.24it/s]
# Temporal encoding
# 93451it [00:06, 13620.46it/s]
# Clustering with 1 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|██████████████████████████████████| 78434/78434 [00:04<00:00, 16140.73it/s]
# 78434it [00:05, 14286.60it/s]
# Evaluating test vectors
# Processed in 21.65 seconds
# Frames: 15315
# Efficiency: 1.4138664017695055ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|██████████████████████████████████| 93451/93451 [00:05<00:00, 17902.47it/s]
# Temporal encoding
# 93451it [00:06, 13422.71it/s]
# Clustering with 1 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|██████████████████████████████████| 78434/78434 [00:04<00:00, 17080.66it/s]
# 78434it [00:05, 14347.13it/s]
# Evaluating test vectors
# Processed in 21.03 seconds
# Frames: 15315
# Efficiency: 1.372904019382239ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|██████████████████████████████████| 93451/93451 [00:05<00:00, 17878.31it/s]
# Temporal encoding
# 93451it [00:06, 13667.16it/s]
# Clustering with 1 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|██████████████████████████████████| 78434/78434 [00:04<00:00, 16927.03it/s]
# 78434it [00:05, 13976.15it/s]
# Evaluating test vectors
# Processed in 21.51 seconds
# Frames: 15315
# Efficiency: 1.4041949050161056ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|██████████████████████████████████| 93451/93451 [00:05<00:00, 16955.00it/s]
# Temporal encoding
# 93451it [00:10, 8692.23it/s]
# Clustering with 1 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|██████████████████████████████████| 78434/78434 [00:04<00:00, 16310.64it/s]
# 78434it [00:09, 8676.19it/s]
# Evaluating test vectors
# Processed in 24.67 seconds
# Frames: 15315
# Efficiency: 1.6109166097064989ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|██████████████████████████████████| 93451/93451 [00:05<00:00, 17820.37it/s]
# Temporal encoding
# 93451it [00:12, 7771.97it/s]
# Clustering with 1 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|██████████████████████████████████| 78434/78434 [00:04<00:00, 17389.52it/s]
# 78434it [00:09, 8415.05it/s]
# Evaluating test vectors
# Processed in 25.34 seconds
# Frames: 15315
# Efficiency: 1.6548706587723878ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|██████████████████████████████████| 93451/93451 [00:06<00:00, 14888.20it/s]
# Temporal encoding
# 93451it [00:12, 7786.90it/s]
# Clustering with 1 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|██████████████████████████████████| 78434/78434 [00:04<00:00, 17472.33it/s]
# 78434it [00:08, 8931.15it/s]
# Evaluating test vectors
# Processed in 24.31 seconds
# Frames: 15315
# Efficiency: 1.5871413657760993ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|██████████████████████████████████| 93451/93451 [00:05<00:00, 18044.34it/s]
# Temporal encoding
# 93451it [00:11, 7895.47it/s]
# Clustering with 1 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|██████████████████████████████████| 78434/78434 [00:04<00:00, 17044.60it/s]
# 78434it [00:08, 8863.92it/s]
# Evaluating test vectors
# Processed in 24.71 seconds
# Frames: 15315
# Efficiency: 1.6137266018948755ms per frame
# Building encoding dataframe
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# Encoding VSA
# 100%|██████████████████████████████████| 93451/93451 [00:05<00:00, 17914.37it/s]
# Temporal encoding
# 93451it [00:11, 7952.89it/s]
# Clustering with 1 clusters
# Estimating test poses
# Encoding test VSA
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:212: RuntimeWarning: invalid value encountered in divide
#   cos_theta = np.sum(ba * bc, axis=1) / (np.linalg.norm(ba, axis=1) * np.linalg.norm(bc, axis=1))
# /Users/joelewis/Desktop/Dissertation/VSA-Human-VAD/src/vsa_encoding.py:244: RuntimeWarning: All-NaN axis encountered
#   knee_angle = np.nanmax([l_angle, r_angle], axis=0)
# 100%|██████████████████████████████████| 78434/78434 [00:04<00:00, 17469.17it/s]
# 78434it [00:08, 8832.26it/s]
# Evaluating test vectors
# Processed in 24.53 seconds
# Frames: 15315
# Efficiency: 1.6014478660431555ms per frame
